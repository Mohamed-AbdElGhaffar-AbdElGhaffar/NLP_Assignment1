# %% [markdown]
# # Ahmed Mohamed Ahemd 20200036
# # Mohamed Abd ElGhaffar  20200460
# # Mohamed Essam Galal     20200465

# %% [markdown]
# #

# %% [markdown]
# ## Importing Libraries

# %%
import requests
from bs4 import BeautifulSoup
import re
import nltk
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

# %% [markdown]
# ## Reading Text from URL

# %%
def read_text_from_url(url):
    try:

        response = requests.get(url)
        content = BeautifulSoup(response.content, 'html.parser')
        text = content.get_text()
        
        return text
    
    except Exception as e:
        print("Error:", e)
        return None

# %% [markdown]
# ## Tokenization | Stemming | Lemmatization

# %%
def tokenize(preprocessed_words):
    return nltk.word_tokenize(preprocessed_words)

def stemming(word):
    stemmer = PorterStemmer()
    return stemmer.stem(word)

def lemmatizing(word):
    lemmatizer = WordNetLemmatizer()
    return lemmatizer.lemmatize(word)

# %% [markdown]
# ## Preprocessing

# %%
def preprocessing(text):
    preprocessed_text = re.sub(r'\s+', ' ', text)                            # Remove All WhiteSpaces
    preprocessed_text = re.sub(r'[^a-zA-Z0-9\s]', '',preprocessed_text)      # Remove All Charchters Excepts Letters and Numbers
    norm_preprocessed_text = preprocessed_text.lower()                       # Lower All Words "Normalization"
    tokens = tokenize(norm_preprocessed_text)                                # Tokenizzing
    
    stop_words = stopwords.words('english')                                  # Stop-Words to be Removed
    
    stem_words = [stemming(word) for word in tokens if word not in stop_words] # Stemming
    
    lemmatize_words = [lemmatizing(word) for word in tokens if word not in stop_words] # Lemmatizing
    
    return norm_preprocessed_text, tokens, stem_words, lemmatize_words

# %% [markdown]
# ## Getting Unique Words

# %%
def unique_words(stem_words = None, lemmatize_words = None):
    try:
        return set(lemmatize_words), set(stem_words)
    except Exception as e:
        print("Error:", e)
        return None

# %% [markdown]
# ## Testing

# %%
url = 'https://www.wwe.com/'
html_text = read_text_from_url(url)

# %%
norm_preprocessed_text, tokens, stem_words, lemmatize_words = preprocessing(html_text)

# %%
stem_unique_words, lemmatize_unique_words = unique_words(stem_words, lemmatize_words)

# %% [markdown]
# ## Output

# %%
html_text
# Out:
# "\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nWWE News, Results, Photos & Video - Official Site | WWE\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \nSkip to main content\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\nWWE Network\n\n\nShows\n\n\nSuperstars\n\n\nTickets\n\n\nShop\n\n\n\n\n\nWatch every Premium Live Event and get unlimited access to WWE's premium content - available to you anywhere, anytime, on any device.\nGo to WWE Network\n\n\n\n\n\nSign up for Peacock to watch. Plus, get every WWE Premium Live Event, your favorite shows, new movies, live sports, and more.\nGo to Peacock\n\n\n\n\n\nVisit Sony LIV to sign in or sign up and enjoy WWE's premium content.\nGo to Sony LIV\n\n\n\n\n\nWatch every Premium Live Event and enjoy some of your favorite WWE content on Shahid.\nGo to Shahid\n\n\n\n\n\nWatch every Premium Live Event and enjoy some of your favorite WWE content on Disney + HotStar.\nGo to Disney + Hotstar\n\n\n\n\n\nWatch WrestleMania and other WWE Premium Live Events on Flow.\nGo to Flow\n\n\n\n\n\nSign up for BINGE to watch. Plus, get every WWE Premium Live Event and the world’s best TV and movies\nGET BINGE NNOW\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nWWE Network\n\n\nShows\n\n\nSuperstars\n\n\nTickets\n\n\nShop\n\n\n\n\n\n\nWatch every Premium Live Event and get unlimited access to WWE's premium content - available to you anywhere, anytime, on any device.\nGo to WWE Network\n\n\n\n\n\n\n\nSign up for Peacock to watch. Plus, get every WWE Premium Live Event, your favorite shows, new movies, live sports, and more.\nGo to Peacock\n\n\n\n\n\n\n\nVisit Sony LIV to sign in or sign up and enjoy WWE's premium content.\nGo to Sony LIV\n\n\n\n\n\n\n\nWatch every Premium Live Event and enjoy some of your favorite WWE content on Shahid.\nGo to Shahid\n\n\n\n\n\n\n\nWatch every Premium Live Event and enjoy some of your favorite WWE content on Disney + HotStar.\nGo to Disney + Hotstar\n\n\n\n\n\n\n\nWatch WrestleMania and other WWE Premium Live Events on Flow.\nGo to Flow\n\n\n\n\n\n\n\nSign up for BINGE to watch. Plus, get every WWE Premium Live Event and the world’s best TV and movies\nGET BINGE NNOW\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n \n\xa0\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\nfacebook\n\n\ntwitter\n\n\n\n\n\n\n\n\nMore Share Options\n\n\n\n\n\n\nShare\nclose\n\n\n\nfacebook\n\n\n\n\ntwitter\n\n\n\n\ntumblr\n\n\n\n\npinterest\n\n\n\n\nemail\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n                                  WWE NXT results for 3/12                              \n\n\n\n                Trick Williams wants Carmelo Hayes at NXT Stand & Deliver              \n\n\n\n\n\n\nfacebook\n\n\ntwitter\n\n\n\n\n\n\n\n\nMore Share Options\n\n\n\n\n\n\nShare\nclose\n\n\n\nfacebook\n\n\n\n\ntwitter\n\n\n\n\ntumblr\n\n\n\n\npinterest\n\n\n\n\nemail\n\n\n\n\n\n\n\nResults Watch Highlights \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n                                              WWE NXT results for 3/12                                          \n\n\n\n                      Oba Femi decimates Brooks Jensen                    \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n                                              WWE NXT results for 3/12                                          \n\n\n\n                      Roxanne Perez demands to be named champion                    \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n                                              WWE NXT results for 3/12                                          \n\n\n\n                      Tony D’Angelo abducts NXT Champion Ilja Dragunov                    \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nTrending\nWWE News\n\nMore WWE News\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\nWWE surpasses 100 million subscriber mark on YouTube \n\n\n\n\nfacebook\n\n\ntwitter\n\n\n\n\n\n\n\ ...

# %%
norm_preprocessed_text
# Out:
# ' wwe news results photos  video  official site  wwe skip to main content wwe network shows superstars tickets shop watch every premium live event and get unlimited access to wwes premium content  available to you anywhere anytime on any device go to wwe network sign up for peacock to watch plus get every wwe premium live event your favorite shows new movies live sports and more go to peacock visit sony liv to sign in or sign up and enjoy wwes premium content go to sony liv watch every premium live event and enjoy some of your favorite wwe content on shahid go to shahid watch every premium live event and enjoy some of your favorite wwe content on disney  hotstar go to disney  hotstar watch wrestlemania and other wwe premium live events on flow go to flow sign up for binge to watch plus get every wwe premium live event and the worlds best tv and movies get binge nnow wwe network shows superstars tickets shop watch every premium live event and get unlimited access to wwes premium content  available to you anywhere anytime on any device go to wwe network sign up for peacock to watch plus get every wwe premium live event your favorite shows new movies live sports and more go to peacock visit sony liv to sign in or sign up and enjoy wwes premium content go to sony liv watch every premium live event and enjoy some of your favorite wwe content on shahid go to shahid watch every premium live event and enjoy some of your favorite wwe content on disney  hotstar go to disney  hotstar watch wrestlemania and other wwe premium live events on flow go to flow sign up for binge to watch plus get every wwe premium live event and the worlds best tv and movies get binge nnow facebook twitter more share options share close facebook twitter tumblr pinterest email wwe nxt results for 312 trick williams wants carmelo hayes at nxt stand  deliver facebook twitter more share options share close facebook twitter tumblr pinterest email results watch highlights wwe nxt results for 312 oba femi decimates brooks jensen wwe nxt results for 312 roxanne perez demands to be named champion wwe nxt results for 312 tony dangelo abducts nxt champion ilja dragunov trending wwe news more wwe news wwe surpasses 100 million subscriber mark on youtube facebook twitter more share options share close facebook twitter tumblr pinterest email sami zayn looks for wrestlemania glory against intercontinental champion gunther facebook twitter more share options share close facebook twitter tumblr pinterest email cleveland to host summerslam 2024 facebook twitter more share options share close facebook twitter tumblr pinterest email thunderbolt patterson to be inducted into wwe hall of fame class of 2024 facebook twitter more share options share close facebook twitter tumblr pinterest email more wwe news toggle menuhome shows superstars tickets  events shop wwe network sign in follow wwe on facebook follow wwe on twitter follow wwe on instagram follow wwe on reddit follow wwe on youtube wwe news wwe photos wwe videos corporate careers community contact worldwide wwe music wwe studios privacy policy copyright terms  conditions faq redeem gift card security corporate corporate careers impact contact wwecom wwe news wwe videos wwe photos wwe worldwide priority pass about privacy policy copyright terms of use cookie preferences do not sell or share my info help security help center redeem gift card cookie policy closed captions global sites arabic '

# %%
tokens
# Out:
# ['wwe',
#  'news',
#  'results',
#  'photos',
#  'video',
#  'official',
#  'site',
#  'wwe',
#  'skip',
#  'to',
#  'main',
#  'content',
#  'wwe',
#  'network',
#  'shows',
#  'superstars',
#  'tickets',
#  'shop',
#  'watch',
#  'every',
#  'premium',
#  'live',
#  'event',
#  'and',
#  'get',
#  'unlimited',
#  'access',
#  'to',
#  'wwes',
#  'premium',
#  'content',
#  'available',
#  'to',
#  'you',
#  'anywhere',
#  'anytime',
#  'on',
#  'any',
#  'device',
#  'go',
#  'to',
#  'wwe',
#  'network',
#  'sign',
#  'up',
#  'for',
#  'peacock',
#  'to',
#  'watch',
#  'plus',
#  'get',
#  'every',
#  'wwe',
#  'premium',
#  'live',
#  'event',
#  'your',
#  'favorite',
#  'shows',
#  'new',
#  'movies',
#  'live',
#  'sports',
#  'and',
#  'more',
#  'go',
#  'to',
#  'peacock',
#  'visit',
#  'sony',
#  'liv',
#  'to',
#  'sign',
#  'in',
#  'or',
#  'sign',
#  'up',
#  'and',
#  'enjoy',
#  'wwes',
#  'premium',
#  'content',
#  'go',
#  'to',
#  'sony',
#  'liv',
#  'watch',
#  'every',
#  'premium',
#  'live',
#  'event',
#  'and',
#  'enjoy',
#  'some',
#  'of',
#  'your',
#  'favorite',
#  'wwe',
#  'content',
#  'on',
#  'shahid',
#  'go',
#  'to',
#  'shahid',
#  'watch',
#  'every',
#  'premium',
#  'live',
#  'event',
#  'and',
#  'enjoy',
#  'some',
#  'of',
#  'your',
#  'favorite',
#  'wwe',
#  'content',
#  'on',
#  'disney',
#  'hotstar',
#  'go',
#  'to',
#  'disney',
#  'hotstar',
#  'watch',
#  'wrestlemania',
#  'and',
#  'other',
#  'wwe',
#  'premium',
#  'live',
#  'events',
#  'on',
#  'flow',
#  'go',
#  'to',
#  'flow',
#  'sign',
#  'up',
#  'for',
#  'binge',
#  'to',
#  'watch',
#  'plus',
#  'get',
#  'every',
#  'wwe',
#  'premium',
#  'live',
#  'event',
#  'and',
#  'the',
#  'worlds',
#  'best',
#  'tv',
#  'and',
#  'movies',
#  'get',
#  'binge',
#  'nnow',
#  'wwe',
#  'network',
#  'shows',
#  'superstars',
#  'tickets',
#  'shop',
#  'watch',
#  'every',
#  'premium',
#  'live',
#  'event',
#  'and',
#  'get',
#  'unlimited',
#  'access',
#  'to',
#  'wwes',
#  'premium',
#  'content',
#  'available',
#  'to',
#  'you',
#  'anywhere',
#  'anytime',
#  'on',
#  'any',
#  'device',
#  'go',
#  'to',
#  'wwe',
#  'network',
#  'sign',
#  'up',
#  'for',
#  'peacock',
#  'to',
#  'watch',
#  'plus',
#  'get',
#  'every',
#  'wwe',
#  'premium',
#  'live',
#  'event',
#  'your',
#  'favorite',
#  'shows',
#  'new',
#  'movies',
#  'live',
#  'sports',
#  'and',
#  'more',
#  'go',
#  'to',
#  'peacock',
#  'visit',
#  'sony',
#  'liv',
#  'to',
#  'sign',
#  'in',
#  'or',
#  'sign',
#  'up',
#  'and',
#  'enjoy',
#  'wwes',
#  'premium',
#  'content',
#  'go',
#  'to',
#  'sony',
#  'liv',
#  'watch',
#  'every',
#  'premium',
#  'live',
#  'event',
#  'and',
#  'enjoy',
#  'some',
#  'of',
#  'your',
#  'favorite',
#  'wwe',
#  'content',
#  'on',
#  'shahid',
#  'go',
#  'to',
#  'shahid',
#  'watch',
#  'every',
#  'premium',
#  'live',
#  'event',
#  'and',
#  'enjoy',
#  'some',
#  'of',
#  'your',
#  'favorite',
#  'wwe',
#  'content',
#  'on',
#  'disney',
#  'hotstar',
#  'go',
#  'to',
#  'disney',
#  'hotstar',
#  'watch',
#  'wrestlemania',
#  'and',
#  'other',
#  'wwe',
#  'premium',
#  'live',
#  'events',
#  'on',
#  'flow',
#  'go',
#  'to',
#  'flow',
#  'sign',
#  'up',
#  'for',
#  'binge',
#  'to',
#  'watch',
#  'plus',
#  'get',
#  'every',
#  'wwe',
#  'premium',
#  'live',
#  'event',
#  'and',
#  'the',
#  'worlds',
#  'best',
#  'tv',
#  'and',
#  'movies',
#  'get',
#  'binge',
#  'nnow',
#  'facebook',
#  'twitter',
#  'more',
#  'share',
#  'options',
#  'share',
#  'close',
#  'facebook',
#  'twitter',
#  'tumblr',
#  'pinterest',
#  'email',
#  'wwe',
#  'nxt',
#  'results',
#  'for',
#  '312',
#  'trick',
#  'williams',
#  'wants',
#  'carmelo',
#  'hayes',
#  'at',
#  'nxt',
#  'stand',
#  'deliver',
#  'facebook',
#  'twitter',
#  'more',
#  'share',
#  'options',
#  'share',
#  'close',
#  'facebook',
#  'twitter',
#  'tumblr',
#  'pinterest',
#  'email',
#  'results',
#  'watch',
#  'highlights',
#  'wwe',
#  'nxt',
#  'results',
#  'for',
#  '312',
#  'oba',
#  'femi',
#  'decimates',
#  'brooks',
#  'jensen',
#  'wwe',
#  'nxt',
#  'results',
#  'for',
#  '312',
#  'roxanne',
#  'perez',
#  'demands',
#  'to',
#  'be',
#  'named',
#  'champion',
#  'wwe',
#  'nxt',
#  'results',
#  'for',
#  '312',
#  'tony',
#  'dangelo',
#  'abducts',
#  'nxt',
#  'champion',
#  'ilja',
#  'dragunov',
#  'trending',
#  'wwe',
#  'news',
#  'more',
#  'wwe',
#  'news',
#  'wwe',
#  'surpasses',
#  '100',
#  'million',
#  'subscriber',
#  'mark',
#  'on',
#  'youtube',
#  'facebook',
#  'twitter',
#  'more',
#  'share',
#  'options',
#  'share',
#  'close',
#  'facebook',
#  'twitter',
#  'tumblr',
#  'pinterest',
#  'email',
#  'sami',
#  'zayn',
#  'looks',
#  'for',
#  'wrestlemania',
#  'glory',
#  'against',
#  'intercontinental',
#  'champion',
#  'gunther',
#  'facebook',
#  'twitter',
#  'more',
#  'share',
#  'options',
#  'share',
#  'close',
#  'facebook',
#  'twitter',
#  'tumblr',
#  'pinterest',
#  'email',
#  'cleveland',
#  'to',
#  'host',
#  'summerslam',
#  '2024',
#  'facebook',
#  'twitter',
#  'more',
#  'share',
#  'options',
#  'share',
#  'close',
#  'facebook',
#  'twitter',
#  'tumblr',
#  'pinterest',
#  'email',
#  'thunderbolt',
#  'patterson',
#  'to',
#  'be',
#  'inducted',
#  'into',
#  'wwe',
#  'hall',
#  'of',
#  'fame',
#  'class',
#  'of',
#  '2024',
#  'facebook',
#  'twitter',
#  'more',
#  'share',
#  'options',
#  'share',
#  'close',
#  'facebook',
#  'twitter',
#  'tumblr',
#  'pinterest',
#  'email',
#  'more',
#  'wwe',
#  'news',
#  'toggle',
#  'menuhome',
#  'shows',
#  'superstars',
#  'tickets',
#  'events',
#  'shop',
#  'wwe',
#  'network',
#  'sign',
#  'in',
#  'follow',
#  'wwe',
#  'on',
#  'facebook',
#  'follow',
#  'wwe',
#  'on',
#  'twitter',
#  'follow',
#  'wwe',
#  'on',
#  'instagram',
#  'follow',
#  'wwe',
#  'on',
#  'reddit',
#  'follow',
#  'wwe',
#  'on',
#  'youtube',
#  'wwe',
#  'news',
#  'wwe',
#  'photos',
#  'wwe',
#  'videos',
#  'corporate',
#  'careers',
#  'community',
#  'contact',
#  'worldwide',
#  'wwe',
#  'music',
#  'wwe',
#  'studios',
#  'privacy',
#  'policy',
#  'copyright',
#  'terms',
#  'conditions',
#  'faq',
#  'redeem',
#  'gift',
#  'card',
#  'security',
#  'corporate',
#  'corporate',
#  'careers',
#  'impact',
#  'contact',
#  'wwecom',
#  'wwe',
#  'news',
#  'wwe',
#  'videos',
#  'wwe',
#  'photos',
#  'wwe',
#  'worldwide',
#  'priority',
#  'pass',
#  'about',
#  'privacy',
#  'policy',
#  'copyright',
#  'terms',
#  'of',
#  'use',
#  'cookie',
#  'preferences',
#  'do',
#  'not',
#  'sell',
#  'or',
#  'share',
#  'my',
#  'info',
#  'help',
#  'security',
#  'help',
#  'center',
#  'redeem',
#  'gift',
#  'card',
#  'cookie',
#  'policy',
#  'closed',
#  'captions',
#  'global',
#  'sites',
#  'arabic']

# %%
stem_words
# Out:
# ['wwe',
#  'news',
#  'result',
#  'photo',
#  'video',
#  'offici',
#  'site',
#  'wwe',
#  'skip',
#  'main',
#  'content',
#  'wwe',
#  'network',
#  'show',
#  'superstar',
#  'ticket',
#  'shop',
#  'watch',
#  'everi',
#  'premium',
#  'live',
#  'event',
#  'get',
#  'unlimit',
#  'access',
#  'wwe',
#  'premium',
#  'content',
#  'avail',
#  'anywher',
#  'anytim',
#  'devic',
#  'go',
#  'wwe',
#  'network',
#  'sign',
#  'peacock',
#  'watch',
#  'plu',
#  'get',
#  'everi',
#  'wwe',
#  'premium',
#  'live',
#  'event',
#  'favorit',
#  'show',
#  'new',
#  'movi',
#  'live',
#  'sport',
#  'go',
#  'peacock',
#  'visit',
#  'soni',
#  'liv',
#  'sign',
#  'sign',
#  'enjoy',
#  'wwe',
#  'premium',
#  'content',
#  'go',
#  'soni',
#  'liv',
#  'watch',
#  'everi',
#  'premium',
#  'live',
#  'event',
#  'enjoy',
#  'favorit',
#  'wwe',
#  'content',
#  'shahid',
#  'go',
#  'shahid',
#  'watch',
#  'everi',
#  'premium',
#  'live',
#  'event',
#  'enjoy',
#  'favorit',
#  'wwe',
#  'content',
#  'disney',
#  'hotstar',
#  'go',
#  'disney',
#  'hotstar',
#  'watch',
#  'wrestlemania',
#  'wwe',
#  'premium',
#  'live',
#  'event',
#  'flow',
#  'go',
#  'flow',
#  'sign',
#  'bing',
#  'watch',
#  'plu',
#  'get',
#  'everi',
#  'wwe',
#  'premium',
#  'live',
#  'event',
#  'world',
#  'best',
#  'tv',
#  'movi',
#  'get',
#  'bing',
#  'nnow',
#  'wwe',
#  'network',
#  'show',
#  'superstar',
#  'ticket',
#  'shop',
#  'watch',
#  'everi',
#  'premium',
#  'live',
#  'event',
#  'get',
#  'unlimit',
#  'access',
#  'wwe',
#  'premium',
#  'content',
#  'avail',
#  'anywher',
#  'anytim',
#  'devic',
#  'go',
#  'wwe',
#  'network',
#  'sign',
#  'peacock',
#  'watch',
#  'plu',
#  'get',
#  'everi',
#  'wwe',
#  'premium',
#  'live',
#  'event',
#  'favorit',
#  'show',
#  'new',
#  'movi',
#  'live',
#  'sport',
#  'go',
#  'peacock',
#  'visit',
#  'soni',
#  'liv',
#  'sign',
#  'sign',
#  'enjoy',
#  'wwe',
#  'premium',
#  'content',
#  'go',
#  'soni',
#  'liv',
#  'watch',
#  'everi',
#  'premium',
#  'live',
#  'event',
#  'enjoy',
#  'favorit',
#  'wwe',
#  'content',
#  'shahid',
#  'go',
#  'shahid',
#  'watch',
#  'everi',
#  'premium',
#  'live',
#  'event',
#  'enjoy',
#  'favorit',
#  'wwe',
#  'content',
#  'disney',
#  'hotstar',
#  'go',
#  'disney',
#  'hotstar',
#  'watch',
#  'wrestlemania',
#  'wwe',
#  'premium',
#  'live',
#  'event',
#  'flow',
#  'go',
#  'flow',
#  'sign',
#  'bing',
#  'watch',
#  'plu',
#  'get',
#  'everi',
#  'wwe',
#  'premium',
#  'live',
#  'event',
#  'world',
#  'best',
#  'tv',
#  'movi',
#  'get',
#  'bing',
#  'nnow',
#  'facebook',
#  'twitter',
#  'share',
#  'option',
#  'share',
#  'close',
#  'facebook',
#  'twitter',
#  'tumblr',
#  'pinterest',
#  'email',
#  'wwe',
#  'nxt',
#  'result',
#  '312',
#  'trick',
#  'william',
#  'want',
#  'carmelo',
#  'hay',
#  'nxt',
#  'stand',
#  'deliv',
#  'facebook',
#  'twitter',
#  'share',
#  'option',
#  'share',
#  'close',
#  'facebook',
#  'twitter',
#  'tumblr',
#  'pinterest',
#  'email',
#  'result',
#  'watch',
#  'highlight',
#  'wwe',
#  'nxt',
#  'result',
#  '312',
#  'oba',
#  'femi',
#  'decim',
#  'brook',
#  'jensen',
#  'wwe',
#  'nxt',
#  'result',
#  '312',
#  'roxann',
#  'perez',
#  'demand',
#  'name',
#  'champion',
#  'wwe',
#  'nxt',
#  'result',
#  '312',
#  'toni',
#  'dangelo',
#  'abduct',
#  'nxt',
#  'champion',
#  'ilja',
#  'dragunov',
#  'trend',
#  'wwe',
#  'news',
#  'wwe',
#  'news',
#  'wwe',
#  'surpass',
#  '100',
#  'million',
#  'subscrib',
#  'mark',
#  'youtub',
#  'facebook',
#  'twitter',
#  'share',
#  'option',
#  'share',
#  'close',
#  'facebook',
#  'twitter',
#  'tumblr',
#  'pinterest',
#  'email',
#  'sami',
#  'zayn',
#  'look',
#  'wrestlemania',
#  'glori',
#  'intercontinent',
#  'champion',
#  'gunther',
#  'facebook',
#  'twitter',
#  'share',
#  'option',
#  'share',
#  'close',
#  'facebook',
#  'twitter',
#  'tumblr',
#  'pinterest',
#  'email',
#  'cleveland',
#  'host',
#  'summerslam',
#  '2024',
#  'facebook',
#  'twitter',
#  'share',
#  'option',
#  'share',
#  'close',
#  'facebook',
#  'twitter',
#  'tumblr',
#  'pinterest',
#  'email',
#  'thunderbolt',
#  'patterson',
#  'induct',
#  'wwe',
#  'hall',
#  'fame',
#  'class',
#  '2024',
#  'facebook',
#  'twitter',
#  'share',
#  'option',
#  'share',
#  'close',
#  'facebook',
#  'twitter',
#  'tumblr',
#  'pinterest',
#  'email',
#  'wwe',
#  'news',
#  'toggl',
#  'menuhom',
#  'show',
#  'superstar',
#  'ticket',
#  'event',
#  'shop',
#  'wwe',
#  'network',
#  'sign',
#  'follow',
#  'wwe',
#  'facebook',
#  'follow',
#  'wwe',
#  'twitter',
#  'follow',
#  'wwe',
#  'instagram',
#  'follow',
#  'wwe',
#  'reddit',
#  'follow',
#  'wwe',
#  'youtub',
#  'wwe',
#  'news',
#  'wwe',
#  'photo',
#  'wwe',
#  'video',
#  'corpor',
#  'career',
#  'commun',
#  'contact',
#  'worldwid',
#  'wwe',
#  'music',
#  'wwe',
#  'studio',
#  'privaci',
#  'polici',
#  'copyright',
#  'term',
#  'condit',
#  'faq',
#  'redeem',
#  'gift',
#  'card',
#  'secur',
#  'corpor',
#  'corpor',
#  'career',
#  'impact',
#  'contact',
#  'wwecom',
#  'wwe',
#  'news',
#  'wwe',
#  'video',
#  'wwe',
#  'photo',
#  'wwe',
#  'worldwid',
#  'prioriti',
#  'pass',
#  'privaci',
#  'polici',
#  'copyright',
#  'term',
#  'use',
#  'cooki',
#  'prefer',
#  'sell',
#  'share',
#  'info',
#  'help',
#  'secur',
#  'help',
#  'center',
#  'redeem',
#  'gift',
#  'card',
#  'cooki',
#  'polici',
#  'close',
#  'caption',
#  'global',
#  'site',
#  'arab']

# %%
lemmatize_words
# Out:
# ['wwe',
#  'news',
#  'result',
#  'photo',
#  'video',
#  'official',
#  'site',
#  'wwe',
#  'skip',
#  'main',
#  'content',
#  'wwe',
#  'network',
#  'show',
#  'superstar',
#  'ticket',
#  'shop',
#  'watch',
#  'every',
#  'premium',
#  'live',
#  'event',
#  'get',
#  'unlimited',
#  'access',
#  'wwes',
#  'premium',
#  'content',
#  'available',
#  'anywhere',
#  'anytime',
#  'device',
#  'go',
#  'wwe',
#  'network',
#  'sign',
#  'peacock',
#  'watch',
#  'plus',
#  'get',
#  'every',
#  'wwe',
#  'premium',
#  'live',
#  'event',
#  'favorite',
#  'show',
#  'new',
#  'movie',
#  'live',
#  'sport',
#  'go',
#  'peacock',
#  'visit',
#  'sony',
#  'liv',
#  'sign',
#  'sign',
#  'enjoy',
#  'wwes',
#  'premium',
#  'content',
#  'go',
#  'sony',
#  'liv',
#  'watch',
#  'every',
#  'premium',
#  'live',
#  'event',
#  'enjoy',
#  'favorite',
#  'wwe',
#  'content',
#  'shahid',
#  'go',
#  'shahid',
#  'watch',
#  'every',
#  'premium',
#  'live',
#  'event',
#  'enjoy',
#  'favorite',
#  'wwe',
#  'content',
#  'disney',
#  'hotstar',
#  'go',
#  'disney',
#  'hotstar',
#  'watch',
#  'wrestlemania',
#  'wwe',
#  'premium',
#  'live',
#  'event',
#  'flow',
#  'go',
#  'flow',
#  'sign',
#  'binge',
#  'watch',
#  'plus',
#  'get',
#  'every',
#  'wwe',
#  'premium',
#  'live',
#  'event',
#  'world',
#  'best',
#  'tv',
#  'movie',
#  'get',
#  'binge',
#  'nnow',
#  'wwe',
#  'network',
#  'show',
#  'superstar',
#  'ticket',
#  'shop',
#  'watch',
#  'every',
#  'premium',
#  'live',
#  'event',
#  'get',
#  'unlimited',
#  'access',
#  'wwes',
#  'premium',
#  'content',
#  'available',
#  'anywhere',
#  'anytime',
#  'device',
#  'go',
#  'wwe',
#  'network',
#  'sign',
#  'peacock',
#  'watch',
#  'plus',
#  'get',
#  'every',
#  'wwe',
#  'premium',
#  'live',
#  'event',
#  'favorite',
#  'show',
#  'new',
#  'movie',
#  'live',
#  'sport',
#  'go',
#  'peacock',
#  'visit',
#  'sony',
#  'liv',
#  'sign',
#  'sign',
#  'enjoy',
#  'wwes',
#  'premium',
#  'content',
#  'go',
#  'sony',
#  'liv',
#  'watch',
#  'every',
#  'premium',
#  'live',
#  'event',
#  'enjoy',
#  'favorite',
#  'wwe',
#  'content',
#  'shahid',
#  'go',
#  'shahid',
#  'watch',
#  'every',
#  'premium',
#  'live',
#  'event',
#  'enjoy',
#  'favorite',
#  'wwe',
#  'content',
#  'disney',
#  'hotstar',
#  'go',
#  'disney',
#  'hotstar',
#  'watch',
#  'wrestlemania',
#  'wwe',
#  'premium',
#  'live',
#  'event',
#  'flow',
#  'go',
#  'flow',
#  'sign',
#  'binge',
#  'watch',
#  'plus',
#  'get',
#  'every',
#  'wwe',
#  'premium',
#  'live',
#  'event',
#  'world',
#  'best',
#  'tv',
#  'movie',
#  'get',
#  'binge',
#  'nnow',
#  'facebook',
#  'twitter',
#  'share',
#  'option',
#  'share',
#  'close',
#  'facebook',
#  'twitter',
#  'tumblr',
#  'pinterest',
#  'email',
#  'wwe',
#  'nxt',
#  'result',
#  '312',
#  'trick',
#  'williams',
#  'want',
#  'carmelo',
#  'hayes',
#  'nxt',
#  'stand',
#  'deliver',
#  'facebook',
#  'twitter',
#  'share',
#  'option',
#  'share',
#  'close',
#  'facebook',
#  'twitter',
#  'tumblr',
#  'pinterest',
#  'email',
#  'result',
#  'watch',
#  'highlight',
#  'wwe',
#  'nxt',
#  'result',
#  '312',
#  'oba',
#  'femi',
#  'decimates',
#  'brook',
#  'jensen',
#  'wwe',
#  'nxt',
#  'result',
#  '312',
#  'roxanne',
#  'perez',
#  'demand',
#  'named',
#  'champion',
#  'wwe',
#  'nxt',
#  'result',
#  '312',
#  'tony',
#  'dangelo',
#  'abducts',
#  'nxt',
#  'champion',
#  'ilja',
#  'dragunov',
#  'trending',
#  'wwe',
#  'news',
#  'wwe',
#  'news',
#  'wwe',
#  'surpasses',
#  '100',
#  'million',
#  'subscriber',
#  'mark',
#  'youtube',
#  'facebook',
#  'twitter',
#  'share',
#  'option',
#  'share',
#  'close',
#  'facebook',
#  'twitter',
#  'tumblr',
#  'pinterest',
#  'email',
#  'sami',
#  'zayn',
#  'look',
#  'wrestlemania',
#  'glory',
#  'intercontinental',
#  'champion',
#  'gunther',
#  'facebook',
#  'twitter',
#  'share',
#  'option',
#  'share',
#  'close',
#  'facebook',
#  'twitter',
#  'tumblr',
#  'pinterest',
#  'email',
#  'cleveland',
#  'host',
#  'summerslam',
#  '2024',
#  'facebook',
#  'twitter',
#  'share',
#  'option',
#  'share',
#  'close',
#  'facebook',
#  'twitter',
#  'tumblr',
#  'pinterest',
#  'email',
#  'thunderbolt',
#  'patterson',
#  'inducted',
#  'wwe',
#  'hall',
#  'fame',
#  'class',
#  '2024',
#  'facebook',
#  'twitter',
#  'share',
#  'option',
#  'share',
#  'close',
#  'facebook',
#  'twitter',
#  'tumblr',
#  'pinterest',
#  'email',
#  'wwe',
#  'news',
#  'toggle',
#  'menuhome',
#  'show',
#  'superstar',
#  'ticket',
#  'event',
#  'shop',
#  'wwe',
#  'network',
#  'sign',
#  'follow',
#  'wwe',
#  'facebook',
#  'follow',
#  'wwe',
#  'twitter',
#  'follow',
#  'wwe',
#  'instagram',
#  'follow',
#  'wwe',
#  'reddit',
#  'follow',
#  'wwe',
#  'youtube',
#  'wwe',
#  'news',
#  'wwe',
#  'photo',
#  'wwe',
#  'video',
#  'corporate',
#  'career',
#  'community',
#  'contact',
#  'worldwide',
#  'wwe',
#  'music',
#  'wwe',
#  'studio',
#  'privacy',
#  'policy',
#  'copyright',
#  'term',
#  'condition',
#  'faq',
#  'redeem',
#  'gift',
#  'card',
#  'security',
#  'corporate',
#  'corporate',
#  'career',
#  'impact',
#  'contact',
#  'wwecom',
#  'wwe',
#  'news',
#  'wwe',
#  'video',
#  'wwe',
#  'photo',
#  'wwe',
#  'worldwide',
#  'priority',
#  'pas',
#  'privacy',
#  'policy',
#  'copyright',
#  'term',
#  'use',
#  'cookie',
#  'preference',
#  'sell',
#  'share',
#  'info',
#  'help',
#  'security',
#  'help',
#  'center',
#  'redeem',
#  'gift',
#  'card',
#  'cookie',
#  'policy',
#  'closed',
#  'caption',
#  'global',
#  'site',
#  'arabic']

# %%
stem_unique_words
# Out:
# {'100',
#  '2024',
#  '312',
#  'abducts',
#  'access',
#  'anytime',
#  'anywhere',
#  'arabic',
#  'available',
#  'best',
#  'binge',
#  'brook',
#  'caption',
#  'card',
#  'career',
#  'carmelo',
#  'center',
#  'champion',
#  'class',
#  'cleveland',
#  'close',
#  'closed',
#  'community',
#  'condition',
#  'contact',
#  'content',
#  'cookie',
#  'copyright',
#  'corporate',
#  'dangelo',
#  'decimates',
#  'deliver',
#  'demand',
#  'device',
#  'disney',
#  'dragunov',
#  'email',
#  'enjoy',
#  'event',
#  'every',
#  'facebook',
#  'fame',
#  'faq',
#  'favorite',
#  'femi',
#  'flow',
#  'follow',
#  'get',
#  'gift',
#  'global',
#  'glory',
#  'go',
#  'gunther',
#  'hall',
#  'hayes',
#  'help',
#  'highlight',
#  'host',
#  'hotstar',
#  'ilja',
#  'impact',
#  'inducted',
#  'info',
#  'instagram',
#  'intercontinental',
#  'jensen',
#  'liv',
#  'live',
#  'look',
#  'main',
#  'mark',
#  'menuhome',
#  'million',
#  'movie',
#  'music',
#  'named',
#  'network',
#  'new',
#  'news',
#  'nnow',
#  'nxt',
#  'oba',
#  'official',
#  'option',
#  'pas',
#  'patterson',
#  'peacock',
#  'perez',
#  'photo',
#  'pinterest',
#  'plus',
#  'policy',
#  'preference',
#  'premium',
#  'priority',
#  'privacy',
#  'reddit',
#  'redeem',
#  'result',
#  'roxanne',
#  'sami',
#  'security',
#  'sell',
#  'shahid',
#  'share',
#  'shop',
#  'show',
#  'sign',
#  'site',
#  'skip',
#  'sony',
#  'sport',
#  'stand',
#  'studio',
#  'subscriber',
#  'summerslam',
#  'superstar',
#  'surpasses',
#  'term',
#  'thunderbolt',
#  'ticket',
#  'toggle',
#  'tony',
#  'trending',
#  'trick',
#  'tumblr',
#  'tv',
#  'twitter',
#  'unlimited',
#  'use',
#  'video',
#  'visit',
#  'want',
#  'watch',
#  'williams',
#  'world',
#  'worldwide',
#  'wrestlemania',
#  'wwe',
#  'wwecom',
#  'wwes',
#  'youtube',
#  'zayn'}

# %%
lemmatize_unique_words
# Out:
# {'100',
#  '2024',
#  '312',
#  'abduct',
#  'access',
#  'anytim',
#  'anywher',
#  'arab',
#  'avail',
#  'best',
#  'bing',
#  'brook',
#  'caption',
#  'card',
#  'career',
#  'carmelo',
#  'center',
#  'champion',
#  'class',
#  'cleveland',
#  'close',
#  'commun',
#  'condit',
#  'contact',
#  'content',
#  'cooki',
#  'copyright',
#  'corpor',
#  'dangelo',
#  'decim',
#  'deliv',
#  'demand',
#  'devic',
#  'disney',
#  'dragunov',
#  'email',
#  'enjoy',
#  'event',
#  'everi',
#  'facebook',
#  'fame',
#  'faq',
#  'favorit',
#  'femi',
#  'flow',
#  'follow',
#  'get',
#  'gift',
#  'global',
#  'glori',
#  'go',
#  'gunther',
#  'hall',
#  'hay',
#  'help',
#  'highlight',
#  'host',
#  'hotstar',
#  'ilja',
#  'impact',
#  'induct',
#  'info',
#  'instagram',
#  'intercontinent',
#  'jensen',
#  'liv',
#  'live',
#  'look',
#  'main',
#  'mark',
#  'menuhom',
#  'million',
#  'movi',
#  'music',
#  'name',
#  'network',
#  'new',
#  'news',
#  'nnow',
#  'nxt',
#  'oba',
#  'offici',
#  'option',
#  'pass',
#  'patterson',
#  'peacock',
#  'perez',
#  'photo',
#  'pinterest',
#  'plu',
#  'polici',
#  'prefer',
#  'premium',
#  'prioriti',
#  'privaci',
#  'reddit',
#  'redeem',
#  'result',
#  'roxann',
#  'sami',
#  'secur',
#  'sell',
#  'shahid',
#  'share',
#  'shop',
#  'show',
#  'sign',
#  'site',
#  'skip',
#  'soni',
#  'sport',
#  'stand',
#  'studio',
#  'subscrib',
#  'summerslam',
#  'superstar',
#  'surpass',
#  'term',
#  'thunderbolt',
#  'ticket',
#  'toggl',
#  'toni',
#  'trend',
#  'trick',
#  'tumblr',
#  'tv',
#  'twitter',
#  'unlimit',
#  'use',
#  'video',
#  'visit',
#  'want',
#  'watch',
#  'william',
#  'world',
#  'worldwid',
#  'wrestlemania',
#  'wwe',
#  'wwecom',
#  'youtub',
#  'zayn'}
